# %%
#https://projects.ncsu.edu/crsc/reports/ftp/pdf/crsc-tr06-19.pdf
#https://github.com/lbenz730/world_cup
import pandas as pd
import numpy as np

# %%
int_games = pd.read_csv("https://raw.githubusercontent.com/lbenz730/world_cup/master/international_soccer_game_data.csv")

# %%
int_games['date'] = pd.to_datetime(int_games['date'])

# %%
int_games['recent'] = pd.datetime.now().date() - int_games['date'] 
int_games['GD'] = int_games['home_score'] - int_games['away_score']

# %%
pr_alo = True

# %%
if not pr_alo:
    home_games = int_games[['home_team','away_team','tournament','neutral','recent','date','GD']]
    away_games = int_games[['away_team','home_team','tournament','neutral','recent','date','GD']]
    home_games['loc'] = 'H'
    away_games['loc'] = 'A'
    away_games['GD'] = -1 * away_games['GD']
    col_rename = ['team','opponent','tourney','neutral','recent','date','GD','location']
    away_games.columns = col_rename
    home_games.columns = col_rename
    all_games = pd.concat([away_games,home_games])
    all_games.loc[all_games['neutral'],'location'] = 'N'
    all_games.reset_index(inplace=True)
    relevant_games = all_games[all_games['date'].dt.year > 2014]

# %%
if pr_alo:
    select_df = int_games[['home_team','away_team','tournament','neutral','recent','date','GD']]
    col_renamev2 = ['team','opponent','tourney','neutral','recent','date','GD']
    select_df.columns = col_renamev2
    relevant_games = select_df[select_df['date'].dt.year>=2014]

# %%
def tourney_weights(t_name):
    # WC - 4
    # Continental Cup & Confederations Cup - 3
    three_list = ["AFC Asian Cup","AFC Challenge Cup","African Cup of Nation",
                  "CFU Caribbean Cup","CONCACAF Championship","Gold Cup","Oceania Nations Cup",
                  "UAFA Cup","UEFA Euro","Confederations Cup"]
    # WC Qualifying & CC Qualifying - 2.5
    two_list = ["FIFA World Cup qualification","AFC Asian Cup qualification","AFC Challenge Cup qualification",
                "African Cup of Nations qualification","CFU Caribbean Cup qualification",
                "CONCACAF Championship qualification","Gold Cup qualification",
                "Oceania Nations Cup qualification","UAFA Cup qualification","UEFA Euro qualification"]
    # all others 1
    if t_name == 'FIFA World Cup':
        return 4
    elif t_name in three_list: 
        return 3
    elif t_name in two_list:
        return 2.5
    else:
        return 1

# %%
relevant_games['weights'] = relevant_games['tourney'].apply(tourney_weights)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
relevant_games['GD_recent_weight'] = relevant_games['weights'] * relevant_games['GD'] * np.exp(-1*(relevant_games['recent'].dt.days)/np.max(np.absolute(relevant_games['recent'].dt.days)))
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
relevant_games
# Out:
#                       team        opponent                       tourney  \
# 35239               Kuwait          Jordan             WAFF Championship
# 35240              Bahrain          Jordan             WAFF Championship
# 35241              Namibia           Ghana                      Friendly
# 35242              Nigeria        Ethiopia                      Friendly
# 35243                Qatar          Kuwait             WAFF Championship
# 35244              Bahrain          Kuwait             WAFF Championship
# 35245                Qatar          Jordan             WAFF Championship
# 35246             Zimbabwe           Gabon                      Friendly
# 35247                 Mali         Nigeria  African Nations Championship
# 35248         South Africa      Mozambique  African Nations Championship
# 35249               Uganda    Burkina Faso  African Nations Championship
# 35250             Zimbabwe         Morocco  African Nations Championship
# 35251                Ghana           Congo  African Nations Championship
# 35252                Libya        Ethiopia  African Nations Championship
# 35253             Congo DR      Mauritania  African Nations Championship
# 35254                Gabon         Burundi  African Nations Championship
# 35255              Moldova          Norway                      Friendly
# 35256              Nigeria      Mozambique  African Nations Championship
# 35257         South Africa            Mali  African Nations Championship
# 35258         Burkina Faso         Morocco  African Nations Championship
# 35259             Zimbabwe          Uganda  African Nations Championship
# 35260             Ethiopia           Congo  African Nations Championship
# 35261                Ghana           Libya  African Nations Championship
# 35262              Moldova          Sweden                      Friendly
# 35263              Burundi      Mauritania  African Nations Championship
# 35264             Congo DR           Gabon  African Nations Championship
# 35265               Norway          Poland                      Friendly
# 35266           Mozambique            Mali  African Nations Championship
# 35267         South Africa         Nigeria  African Nations Championship
# 35268         Burkina Faso        Zimbabwe  African Nations Championship
# ...                    ...             ...                           ...
# 38896             Maldives          Bhutan   AFC Asian Cup qualification
# 38897               Mexico         Croatia                      Friendly
# 38898              Moldova     Ivory Coast                      Friendly
# 38899             Mongolia       Mauritius                      Friendly
# 38900           Montenegro          Turkey                      Friendly
# 38901              Morocco      Uzbekistan                      Friendly
# 38902              Namibia         Lesotho                      Friendly
# 38903                 Oman       Palestine   AFC Asian Cup qualification
# 38904                 Peru         Iceland                      Friendly
# 38905          Philippines      Tajikistan   AFC Asian Cup qualification
# 38906               Poland  Korea Republic                      Friendly
# 38907              Romania          Sweden                      Friendly
# 38908               Russia          France                      Friendly
# 38909               Serbia         Nigeria                      Friendly
# 38910           Seychelles       Swaziland                      Friendly
# 38911             Slovenia         Belarus                      Friendly
# 38912                Spain       Argentina                      Friendly
# 38913          Switzerland          Panama                      Friendly
# 38914               Taiwan       Singapore   AFC Asian Cup qualification
# 38915             Tanzania        Congo DR                      Friendly
# 38916              Tunisia      Costa Rica                      Friendly
# 38917               Uganda          Malawi                      Friendly
# 38918              Ukraine           Japan                      Friendly
# 38919                  USA        Paraguay                      Friendly
# 38920                Yemen           Nepal   AFC Asian Cup qualification
# 38921             Malaysia          Bhutan                      Friendly
# 38922  Trinidad and Tobago          Panama                      Friendly
# 38923             Zimbabwe        Botswana                      Friendly
# 38924  St. Kitts and Nevis         Jamaica                      Friendly
# 38925  Antigua and Barbuda         Jamaica                      Friendly
#
#        neutral    recent       date  GD  weights  GD_recent_weight
# 35239     True 1621 days 2014-01-01  -1      1.0         -0.367879
# 35240     True 1618 days 2014-01-04  -1      1.0         -0.368561
# 35241    False 1618 days 2014-01-04  -1      1.0         -0.368561
# 35242    False 1618 days 2014-01-04   1      1.0          0.368561
# 35243    False 1618 days 2014-01-04   3      1.0          1.105683
# 35244     True 1615 days 2014-01-07   0      1.0          0.000000
# 35245    False 1615 days 2014-01-07   2      1.0          0.738487
# 35246     True 1615 days 2014-01-07   2      1.0          0.738487
# 35247     True 1611 days 2014-01-11   1      1.0          0.370156
# 35248    False 1611 days 2014-01-11   2      1.0          0.740312
# 35249     True 1610 days 2014-01-12   1      1.0          0.370384
# 35250     True 1610 days 2014-01-12   0      1.0          0.000000
# 35251     True 1609 days 2014-01-13   1      1.0          0.370613
# 35252     True 1609 days 2014-01-13   2      1.0          0.741226
# 35253     True 1608 days 2014-01-14   1      1.0          0.370842
# 35254     True 1608 days 2014-01-14   0      1.0          0.000000
# 35255     True 1607 days 2014-01-15  -1      1.0         -0.371070
# 35256     True 1607 days 2014-01-15   2      1.0          0.742141
# 35257    False 1607 days 2014-01-15   0      1.0          0.000000
# 35258     True 1606 days 2014-01-16   0      1.0          0.000000
# 35259     True 1606 days 2014-01-16   0      1.0          0.000000
# 35260     True 1605 days 2014-01-17  -1      1.0         -0.371529
# 35261     True 1605 days 2014-01-17   0      1.0          0.000000
# 35262     True 1605 days 2014-01-17  -1      1.0         -0.371529
# 35263     True 1604 days 2014-01-18   1      1.0          0.371758
# 35264     True 1604 days 2014-01-18  -1      1.0         -0.371758
# 35265     True 1604 days 2014-01-18  -3      1.0         -1.115273
# 35266     True 1603 days 2014-01-19  -1      1.0         -0.371987
# 35267    False 1603 days 2014-01-19  -2      1.0         -0.743974
# 35268     True 1602 days 2014-01-20  -1      1.0         -0.372217
# ...        ...       ...        ...  ..      ...               ...
# 38896    False   75 days 2018-03-27   7      2.5         16.708760
# 38897     True   75 days 2018-03-27  -1      1.0         -0.954786
# 38898     True   75 days 2018-03-27  -1      1.0         -0.954786
# 38899    False   75 days 2018-03-27  -2      1.0         -1.909573
# 38900    False   75 days 2018-03-27   0      1.0          0.000000
# 38901    False   75 days 2018-03-27   2      1.0          1.909573
# 38902    False   75 days 2018-03-27   1      1.0          0.954786
# 38903    False   75 days 2018-03-27   1      2.5          2.386966
# 38904     True   75 days 2018-03-27   2      1.0          1.909573
# 38905    False   75 days 2018-03-27   1      2.5          2.386966
# 38906    False   75 days 2018-03-27   1      1.0          0.954786
# 38907    False   75 days 2018-03-27   1      1.0          0.954786
# 38908    False   75 days 2018-03-27  -2      1.0         -1.909573
# 38909     True   75 days 2018-03-27   2      1.0          1.909573
# 38910    False   75 days 2018-03-27   0      1.0          0.000000
# 38911    False   75 days 2018-03-27  -2      1.0         -1.909573
# 38912    False   75 days 2018-03-27   5      1.0          4.773931
# 38913    False   75 days 2018-03-27   6      1.0          5.728718
# 38914    False   75 days 2018-03-27   1      2.5          2.386966
# 38915    False   75 days 2018-03-27   2      1.0          1.909573
# 38916     True   75 days 2018-03-27   1      1.0          0.954786
# 38917    False   75 days 2018-03-27   0      1.0          0.000000
# 38918     True   75 days 2018-03-27   1      1.0          0.954786
# 38919    False   75 days 2018-03-27   1      1.0          0.954786
# 38920     True   75 days 2018-03-27   1      2.5          2.386966
# 38921    False   70 days 2018-04-01   7      1.0          6.704151
# 38922    False   53 days 2018-04-18  -1      1.0         -0.967833
# 38923    False   53 days 2018-04-18  -1      1.0         -0.967833
# 38924    False   45 days 2018-04-26  -2      1.0         -1.945242
# 38925    False   41 days 2018-04-30  -2      1.0         -1.950048
#
# [3687 rows x 9 columns]

# %%
gd_group = relevant_games.groupby(['team','opponent'])['GD_recent_weight'].agg('sum')

# %%
group_scores = gd_group.reset_index()

# %%
group_scores=group_scores.rename(columns = {'GD_recent_weight':'GD'})

# %%
test = group_scores[group_scores['GD'] == 0]
test['GD'] = -(0.5)
add_values = group_scores.append(test)
add_values.reset_index(inplace=True)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
add_values.loc[add_values['GD'] == 0,'GD'] = 0.5

# %%
def create_from(row):
    if row['GD']<0:
        return row['team']
    else:
        return row['opponent']
def create_to(row):
    if row['GD']>0:
        return row['team']
    else: 
        return row['opponent']

# %%
from_scores = add_values
from_scores['from'] = from_scores.apply(create_from, axis=1)
from_scores['to'] = from_scores.apply(create_to,axis=1)

# %%
from_scores['GD'] = np.absolute(from_scores['GD'])
final_graph_df = from_scores[['from','to','GD']]

# %%
final_graph_df.reset_index(inplace=True)

# %%
simple_group_df = final_graph_df.groupby(['from','to'])['GD'].agg('sum')

# %%
simple_df = simple_group_df.reset_index()

# %% [markdown]
# ### Final Start Page Rank

# %%
import networkx as nx

# %%
G=nx.from_pandas_dataframe(simple_df, source='from', target='to', edge_attr='GD',create_using=nx.DiGraph())

# %%
w_ng = nx.pagerank(G)

# %%
sorted_w = sorted(w_ng.items(), key=lambda x: x[1],reverse=True)

# %%
w_df = pd.DataFrame.from_dict(w_ng.items())

# %%
w_df['scaled'] = (w_df[1] - w_df[1].mean())/w_df[1].std()

# %%
w_df['rank'] = w_df['scaled'].rank(ascending=False)

# %% [markdown]
# ## Compare to World Cup Teams

# %%
world_cup = pd.read_csv("https://raw.githubusercontent.com/lbenz730/world_cup/master/fixtures.csv")

# %%
teams1 = world_cup['team'].unique()
teams2 = world_cup['opponent'].unique()

# %%
joined_list = list(set([y for x in [teams1, teams2] for y in x]))

# %%
w_df[w_df[0].isin(joined_list)].sort_values('rank')
# Out:
#                   0         1    scaled  rank
# 23          Germany  0.014541  3.148790   1.0
# 36          England  0.013149  2.710363   3.0
# 106          Brazil  0.013136  2.706048   4.0
# 94         Portugal  0.013126  2.702931   5.0
# 11        Argentina  0.012241  2.424359   6.0
# 60           France  0.012211  2.414840   7.0
# 156          Mexico  0.011735  2.264878   8.0
# 25            Spain  0.011689  2.250291  11.0
# 164        Colombia  0.011193  2.094014  12.0
# 32       Costa Rica  0.010769  1.960436  13.0
# 135         Belgium  0.010657  1.925250  14.0
# 45          Uruguay  0.010612  1.910966  15.0
# 147         Croatia  0.009668  1.613575  17.0
# 120         Nigeria  0.009600  1.592100  19.0
# 190          Poland  0.009354  1.514754  20.0
# 90           Russia  0.009240  1.478774  22.0
# 183         Senegal  0.009095  1.433162  23.0
# 149     Switzerland  0.009049  1.418565  24.0
# 71   Korea Republic  0.009031  1.412940  25.0
# 85           Sweden  0.008749  1.324019  28.0
# 181         Iceland  0.008535  1.256835  29.0
# 17            Japan  0.008324  1.190394  31.0
# 125            Iran  0.008308  1.185395  32.0
# 208         Tunisia  0.007908  1.059121  33.0
# 143         Denmark  0.007441  0.912166  39.0
# 146         Morocco  0.007189  0.832699  43.0
# 124       Australia  0.007036  0.784557  44.0
# 211          Serbia  0.006382  0.578516  54.0
# 64             Peru  0.006223  0.528551  56.0
# 16     Saudi Arabia  0.005744  0.377432  65.0
# 159           Egypt  0.005438  0.281126  77.0
# 109          Panama  0.005329  0.246945  78.0
